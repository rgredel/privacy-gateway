# %% [markdown]
# # Example Jupyter Notebook
#
# This is a simple example of a Jupyter Notebook created by Antigravity.

# %%
def greet(name):
    """This function greets the person passed in as a parameter"""
    print(f"Hello, {name}! Welcome to Jupyter.")

greet("World")
# Out:
# Hello, World! Welcome to Jupyter.

# %%
import math

for i in range(1, 6):
    print(f"The square root of {i} is {math.sqrt(i):.2f}")
# Out:
# The square root of 1 is 1.00
# The square root of 2 is 1.41
# The square root of 3 is 1.73
# The square root of 4 is 2.00
# The square root of 5 is 2.24
